# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import pandas as pd
import seaborn as sns
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
file_path = "ai_impact_on_students.csv"
df = kagglehub.load_dataset(
    KaggleDatasetAdapter.PANDAS,
    "owner/valid-dataset-slug",
    "file.csv"
)
df
# Out:
# /tmp/ipykernel_5206/2300804660.py:2: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/exceptions.py:67, in handle_call(fn, resource_handle)
#      66 try:
# ---> 67     return fn()
#      68 except requests.HTTPError as e:
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/http_resolver.py:364, in _get_current_version.<locals>.<lambda>()
#     363 r.dataset_slug = h.dataset
# --> 364 dataset = handle_call(lambda: api_client.datasets.dataset_api_client.get_dataset(r))
#     365 return dataset.current_version_number
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglesdk/datasets/services/dataset_api_service.py:33, in DatasetApiClient.get_dataset(self, request)
#      31   request = ApiGetDatasetRequest()
# ---> 33 return self._client.call("datasets.DatasetApiService", "GetDataset", request, ApiDataset)
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglesdk/kaggle_http_client.py:106, in KaggleHttpClient.call(self, service_name, request_name, request, response_type)
#     104 http_response = self._session.send(http_request, **settings)
# --> 106 response = self._prepare_response(response_type, http_response)
#     107 return response
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglesdk/kaggle_http_client.py:136, in KaggleHttpClient._prepare_response(self, response_type, http_response)
#     135     pass
# --> 136 http_response.raise_for_status()
#     137 # Allow client to check header content.
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/requests/models.py:1167, in Response.raise_for_status(self)
#    1166 if http_error_msg:
# -> 1167     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDataset
#
# The above exception was the direct cause of the following exception:
#
# KaggleApiHTTPError                        Traceback (most recent call last)
# Cell In[18], line 2
#       1 file_path = "ai_impact_on_students.csv"
# ----> 2 df = kagglehub.load_dataset(
#       3     KaggleDatasetAdapter.PANDAS,
#       4     "owner/valid-dataset-slug",
#       5     "file.csv"
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/datasets.py:192, in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     177 def load_dataset(
#     178     adapter: KaggleDatasetAdapter,
#     179     # In the form of {owner_slug}/{dataset_slug} or {owner_slug}/{dataset_slug}/versions/{version_number}
#    (...)    185     hf_kwargs: Any = None,  # noqa: ANN401
#     186 ) -> Any:  # noqa: ANN401
#     187     warnings.warn(
#     188         "Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.",
#     189         DeprecationWarning,
#     190         stacklevel=2,
#     191     )
# --> 192     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/datasets.py:155, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs, polars_frame_type, polars_kwargs)
#     152 elif adapter is KaggleDatasetAdapter.PANDAS:
#     153     import kagglehub.pandas_datasets  # noqa: PLC0415
# --> 155     return kagglehub.pandas_datasets.load_pandas_dataset(
#     156         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     157     )
#     158 elif adapter is KaggleDatasetAdapter.POLARS:
#     159     import kagglehub.polars_datasets  # noqa: PLC0415
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/pandas_datasets.py:90, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      87 read_function = _validate_read_function(file_extension, sql_query)
#      89 # Now that everything has been validated, we can start downloading and processing
# ---> 90 filepath = dataset_download(handle, path)
#      91 try:
#      92     result = read_function(
#      93         *_build_args(read_function, filepath, sql_query),
#      94         **_build_kwargs(file_extension, pandas_kwargs),
#      95     )
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/datasets.py:52, in dataset_download(handle, path, force_download, output_dir)
#      50 h = parse_dataset_handle(handle)
#      51 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 52 resolved_path, _ = registry.dataset_resolver(
#      53     h,
#      54     path,
#      55     force_download=force_download,
#      56     output_dir=output_dir,
#      57 )
#      58 return resolved_path
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/resolver.py:35, in Resolver.__call__(self, handle, path, force_download, output_dir)
#      15 def __call__(
#      16     self,
#      17     handle: T,
#    (...)     21     output_dir: str | None = None,
#      22 ) -> tuple[str, int | None]:
#      23     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      24
#      25     Args:
#    (...)     33         Some cases where version number might be missing: Competition datasource, API-based models.
#      34     """
# ---> 35     path, version = self._resolve(
#      36         handle,
#      37         path,
#      38         force_download=force_download,
#      39         output_dir=output_dir,
#      40     )
#      42     # Note handles are immutable, so _resolve() could not have altered our reference
#      43     register_datasource_access(handle, version)
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/http_resolver.py:125, in DatasetHttpResolver._resolve(self, h, path, force_download, output_dir)
#     123 with build_kaggle_client() as api_client:
#     124     if not h.is_versioned():
# --> 125         h = h.with_version(_get_current_version(api_client, h))
#     127     cache = Cache(override_dir=output_dir)
#     128     dataset_path = cache.load_from_cache(h, path)
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/http_resolver.py:364, in _get_current_version(api_client, h)
#     362     r.owner_slug = h.owner
#     363     r.dataset_slug = h.dataset
# --> 364     dataset = handle_call(lambda: api_client.datasets.dataset_api_client.get_dataset(r))
#     365     return dataset.current_version_number
#     367 elif isinstance(h, NotebookHandle):
#
# File ~/Documents/@Code (Copy)/.venv/lib/python3.12/site-packages/kagglehub/exceptions.py:107, in handle_call(fn, resource_handle)
#      98     message = (
#      99         f"{e.response.status_code} Client Error."
#     100         "\n\n"
#    (...)    103         "Please make sure you specified the correct resource identifiers."
#     104     )
#     106 # Default handling
# --> 107 raise KaggleApiHTTPError(message, response=e.response) from e
#
# KaggleApiHTTPError: 403 Client Error.
#
# You don't have permission to access resource at URL: https://api.kaggle.com/v1/datasets.DatasetApiService/GetDataset. Please make sure you are authenticated if you are trying to access a private resource or a resource requiring consent.
