# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import zipfile

# %%
# 1_Computer_Vision/zz9_Material/Datasets/cat_dog_1.zip
path = '../../zz9_Material/Datasets/cat_dog_1.zip'
zip_object= zipfile.ZipFile(file= path, mode = 'r')
zip_object.extractall('../zz9_Material/Datasets/')
zip_object.close()

# %%
testdir = '../zz9_Material/Datasets/cat_dog_1/test/'
traindir = '../zz9_Material/Datasets/cat_dog_1/train/'
test = [os.path.join(testdir, f) for f in sorted(os.listdir(testdir)) if f.endswith(('.jpg', '.png'))]
train = [os.path.join(traindir, f) for f in sorted(os.listdir(traindir)) if f.endswith(('.jpg', '.png'))]

# %%
files =
# Out:
# ['../zz9_Material/Datasets/cat_dog_1/test/cat.3500.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3501.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3502.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3503.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3504.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3505.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3506.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3507.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3508.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3509.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3510.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3511.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3512.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3513.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3514.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3515.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.3516.jpg', '../zz9_Material/Datasets/cat_dog_1/test/cat.
# ...

# %%
h,w = 128,128
images = []
classes = []

for img_path in train
