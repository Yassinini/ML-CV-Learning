# %% [markdown]
# # CSRT to track Usain Bolt

# %% [markdown]
# ## Import cv2

# %%
import cv2 as cv

# %% [markdown]
# ## Initialise Tracker and Video

# %%
from pathlib import Path

# Get repo root for file paths
repo_root = Path.cwd()
while repo_root.name != 'Machine_Learning' and repo_root.parent != repo_root:
    repo_root = repo_root.parent
course_materials = repo_root / 'computer_vision' / 'Course_Materials'

tracker = cv.TrackerCSRT_create()
vid = cv.VideoCapture(str(course_materials / 'Videos' / 'race.mp4'))
ok, frame = vid.read()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 9
#       5 while repo_root.name != 'Machine_Learning' and repo_root.parent != repo_root:
#       6     repo_root = repo_root.parent
#       7 course_materials = repo_root / 'computer_vision' / 'Course_Materials'
#       8
# ----> 9 tracker = cv.TrackerCSRT_create()
#      10 vid = cv.VideoCapture(str(course_materials / 'Videos' / 'race.mp4'))
#      11 ok, frame = vid.read()
#
# AttributeError: module 'cv2' has no attribute 'TrackerCSRT_create'

# %%
boundbox = cv.selectROI("Select Object", frame)
cv.destroyWindow("Select Object")
ok = tracker.init(frame, boundbox)

# %% [markdown]
# ## Video

# %%
while True:
    ok , frame = vid.read()
    if not ok:
        break
    ok , boundbox = tracker.update(frame)
    if ok:
        x,y,w,h = [int(v) for v in boundbox]
        cv.rectangle(frame, (x,y), (x+w, y+h), (255,0,0), 2)
    else:
        cv.putText("I CANT SEEEEEEEE", (100,80), cv.FONT_HERSHEY_SIMPLEX, 1, (255,0,0), 2)
    cv.imshow("Video", frame)
    if cv.waitKey(1) & 0xFF == 27:
        break
vid.release()
cv.destroyAllWindows()
